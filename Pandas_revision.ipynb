# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("")

# %%
l = [[2,3],[4,4]]
np.array(l).shape
# Out:
# (2, 2)

# %%
help(np.array)
# Out:
# Help on built-in function array in module numpy:
#
# array(...)
#     array(object, dtype=None, *, copy=True, order='K', subok=False, ndmin=0,
#           like=None)
#
#     Create an array.
#
#     Parameters
#     ----------
#     object : array_like
#         An array, any object exposing the array interface, an object whose
#         ``__array__`` method returns an array, or any (nested) sequence.
#         If object is a scalar, a 0-dimensional array containing object is
#         returned.
#     dtype : data-type, optional
#         The desired data-type for the array. If not given, NumPy will try to use
#         a default ``dtype`` that can represent the values (by applying promotion
#         rules when necessary.)
#     copy : bool, optional
#         If true (default), then the object is copied.  Otherwise, a copy will
#         only be made if ``__array__`` returns a copy, if obj is a nested
#         sequence, or if a copy is needed to satisfy any of the other
# ...

# %%
arr1 = np.array([2,6,1,18,15,12,45,17,88]).reshape(3,3)
arr1
# Out:
# array([[ 2,  6,  1],
#        [18, 15, 12],
#        [45, 17, 88]])

# %%
arr1[:2,[1,2]]
# Out:
# array([[ 6,  1],
#        [15, 12]])

# %%
arr1[::2,::2]
# Out:
# array([[ 2,  1],
#        [45, 88]])

# %%
arr1[[0,2],::2]
# Out:
# array([[ 2,  1],
#        [45, 88]])

# %%
arr1[:,:]
# Out:
# array([[ 2,  6,  1],
#        [18, 15, 12],
#        [45, 17, 88]])

# %%
arr1[[0,2],[0,2]]
# Out:
# array([ 2, 88])

# %%
import random
np.random.randint(2,5,1)
# Out:
# array([4])

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
np.random.randn(40)

sns.distplot(np.random.randn(40))
# Out:
# <Axes: ylabel='Density'>

# %%
# Pandas

# %%
dt = pd.date_range('2025-11-08',periods = 4, freq = '3M')

# %%
df = pd.DataFrame({'Day' : ['Mon','Tue','Wed','Thu'] ,'temp':[23,12,23,28], 'rained':['yes','no','yes','no']})
df
# Out:
#    Day  temp rained
# 0  Mon    23    yes
# 1  Tue    12     no
# 2  Wed    23    yes
# 3  Thu    28     no

# %%
df[:2]
# Out:
#    Day  temp rained
# 0  Mon    23    yes
# 1  Tue    12     no

# %%
df[['Day','rained']][2:]
# Out:
#    Day rained
# 2  Wed    yes
# 3  Thu     no

# %%
df.index = dt

# %%
df.loc['2026-08-31']['rained']
# Out:
# 'no'

# %%
df.loc['2026-05-31']
# Out:
# Day       Wed
# temp       23
# rained    yes
# Name: 2026-05-31 00:00:00, dtype: object

# %%
df.iloc[:2,[0,2]]
# Out:
#             Day rained
# 2025-11-30  Mon    yes
# 2026-02-28  Tue     no

# %%
df.reset_index()
# Out:
#        index  Day  temp rained
# 0 2025-11-30  Mon    23    yes
# 1 2026-02-28  Tue    12     no
# 2 2026-05-31  Wed    23    yes
# 3 2026-08-31  Thu    28     no

# %%
df.reset_index(drop = True)
# Out:
#    Day  temp rained
# 0  Mon    23    yes
# 1  Tue    12     no
# 2  Wed    23    yes
# 3  Thu    28     no

# %%
df.reset_index(drop = True, inplace = True)

# %%
df['Humidity'] = ['high','low','avg','high']

# %%
df
# Out:
#             Day  temp Humidity rained
# 2025-11-30  Mon    23     high    yes
# 2026-02-28  Tue    12      low     no
# 2026-05-31  Wed    23      avg    yes
# 2026-08-31  Thu    28     high     no

# %%
df.insert(2,'Humidity',['high','low','avg','high'],allow_duplicates = True)

# %%
df.drop('Humidity',axis = 1,inplace = True)

# %%
del[df['Humidity']]

# %%
df['Humidity'][2] = 'avg'

# %%
df
# Out:
#             Day  temp Humidity rained
# 2025-11-30  Mon    23     high    yes
# 2026-02-28  Tue    12      low     no
# 2026-05-31  Wed    23      avg    yes
# 2026-08-31  Thu    28     high     no

# %%
df[df['rained'] == 'yes']
# Out:
#             Day  temp Humidity rained
# 2025-11-30  Mon    23     high    yes
# 2026-05-31  Wed    23      avg    yes

# %%
df[df['rained'].str.lower() == 'yes']
# Out:
#             Day  temp Humidity rained
# 2025-11-30  Mon    23     high    yes
# 2026-05-31  Wed    23      avg    yes

# %%
df[(df['rained'].str.lower() == 'yes') & (df['Day'] == 'Mon')]
# Out:
#             Day  temp Humidity rained
# 2025-11-30  Mon    23     high    yes

# %%
df = pd.read_csv("churn.csv")
df.head()
# Out:
#    CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0    15634602  Hargrave          619    France  Female   42       2
# 1    15647311      Hill          608     Spain  Female   41       1
# 2    15619304      Onio          502    France  Female   42       8
# 3    15701354      Boni          699    France  Female   39       1
# 4    15737888  Mitchell          850     Spain  Female   43       2
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              1          1               1        101348.88
# 1   83807.86              1          0               1        112542.58
# 2  159660.80              3          1               0        113931.57
# 3       0.00              2          0               0         93826.63
# 4  125510.82              1          1               1         79084.10
#
#    Exited
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0

# %%
df.shape
# Out:
# (10000, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerId       10000 non-null  int64
#  1   Surname          10000 non-null  object
#  2   CreditScore      10000 non-null  int64
#  3   Geography        10000 non-null  object
#  4   Gender           10000 non-null  object
#  5   Age              10000 non-null  int64
#  6   Tenure           10000 non-null  int64
#  7   Balance          10000 non-null  float64
#  8   NumOfProducts    10000 non-null  int64
#  9   HasCrCard        10000 non-null  int64
#  10  IsActiveMember   10000 non-null  int64
#  11  EstimatedSalary  10000 non-null  float64
#  12  Exited           10000 non-null  int64
# dtypes: float64(2), int64(8), object(3)
# memory usage: 1015.8+ KB

# %%
#Univariate and Bivariate Analysis

# %%
df[:2]
# Out:
#    CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure   Balance  \
# 0    15634602  Hargrave          619    France  Female   42       2      0.00
# 1    15647311      Hill          608     Spain  Female   41       1  83807.86
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0              1          1               1        101348.88       1
# 1              1          0               1        112542.58       0

# %%
# Measure of central tendency --> Mean, Median, Mode

# %%
sns.distplot(df['CreditScore'])
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_5992\3364146939.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['CreditScore'])
# <Axes: xlabel='CreditScore', ylabel='Density'>

# %%
df['CreditScore'].mean()
# Out:
# 650.5288

# %%
df['CreditScore'].median()
# Out:
# 652.0

# %%
# Measures of Division

# %%
df['CreditScore'].std()
# Out:
# 96.65329873613061

# %%
df['CreditScore'].min()
# Out:
# 350

# %%
df['CreditScore'].max()
# Out:
# 850

# %%
sns.boxplot(df['CreditScore'])
# Out:
# <Axes: ylabel='CreditScore'>

# %%
df['Geography'].nunique()
# Out:
# 3

# %%
df['Geography'].value_counts()
# Out:
# Geography
# France     5014
# Germany    2509
# Spain      2477
# Name: count, dtype: int64

# %%
sns.countplot(x=df['Geography'],hue = df['Exited']) #Multivariate analysis or bivariate analysis
# Out:
# <Axes: xlabel='Geography', ylabel='count'>

# %%
sns.boxplot(x=df['Geography'], y = df['CreditScore'])
# Out:
# <Axes: xlabel='Geography', ylabel='CreditScore'>

# %%
df['CreditScore'].skew()
# Out:
# -0.07160660820092675

# %%
round(df.describe(),2).T
# Out:
#                    count         mean       std          min          25%  \
# CustomerId       10000.0  15690940.57  71936.19  15565701.00  15628528.25
# CreditScore      10000.0       650.53     96.65       350.00       584.00
# Age              10000.0        38.92     10.49        18.00        32.00
# Tenure           10000.0         5.01      2.89         0.00         3.00
# Balance          10000.0     76485.89  62397.41         0.00         0.00
# NumOfProducts    10000.0         1.53      0.58         1.00         1.00
# HasCrCard        10000.0         0.71      0.46         0.00         0.00
# IsActiveMember   10000.0         0.52      0.50         0.00         0.00
# EstimatedSalary  10000.0    100090.24  57510.49        11.58     51002.11
# Exited           10000.0         0.20      0.40         0.00         0.00
#
#                          50%          75%          max
# CustomerId       15690738.00  15753233.75  15815690.00
# ...

# %%
round(df.describe(),2)
# Out:
#         CustomerId  CreditScore       Age    Tenure    Balance  NumOfProducts  \
# count     10000.00     10000.00  10000.00  10000.00   10000.00       10000.00
# mean   15690940.57       650.53     38.92      5.01   76485.89           1.53
# std       71936.19        96.65     10.49      2.89   62397.41           0.58
# min    15565701.00       350.00     18.00      0.00       0.00           1.00
# 25%    15628528.25       584.00     32.00      3.00       0.00           1.00
# 50%    15690738.00       652.00     37.00      5.00   97198.54           1.00
# 75%    15753233.75       718.00     44.00      7.00  127644.24           2.00
# max    15815690.00       850.00     92.00     10.00  250898.09           4.00
#
#        HasCrCard  IsActiveMember  EstimatedSalary   Exited
# count   10000.00        10000.00         10000.00  10000.0
# mean        0.71            0.52        100090.24      0.2
# std         0.46            0.50         57510.49      0.4
# ...

# %%
pd.crosstab(df['Geography'],df['Gender'])
# Out:
# Gender     Female  Male
# Geography
# France       2261  2753
# Germany      1193  1316
# Spain        1089  1388

# %%
df.groupby('Geography').agg({'Balance':['min','max','mean'],'EstimatedSalary':['min','max','mean','std'],'Exited':['mean']})
# Out:
#             Balance                           EstimatedSalary             \
#                 min        max           mean             min        max
# Geography
# France         0.00  238387.56   62092.636516           90.07  199929.17
# Germany    27288.43  214346.96  119730.116134           11.58  199970.74
# Spain          0.00  250898.09   61818.147763          417.41  199992.48
#
#                                           Exited
#                     mean           std      mean
# Geography
# France      99899.180814  57336.289016  0.161548
# Germany    101113.435102  58263.011501  0.324432
# Spain       99440.572281  57103.678091  0.166734

# %%
# Data Cleaning

# %%
df2 = pd.read_csv("diabetes.csv")
df2.head()
# Out:
#    Sl.No pregnant  glucose  pressure  triceps  insulin  mass  pedigree  age  \
# 0      1        6      148        72       35        0  33.6     0.627   50
# 1      2        1       85        66       29        0  26.6     0.351   31
# 2      3        8      183        64        0        0  23.3     0.672   32
# 3      4        1       89        66       23       94  28.1     0.167   21
# 4      5        0      137        40       35      168  43.1     2.288   33
#
#    diabetes
# 0         1
# 1         0
# 2         1
# 3         0
# 4         1

# %%
df2.describe().T
# Out:
#           count        mean         std      min        25%       50%  \
# Sl.No     768.0  384.500000  221.846794    1.000  192.75000  384.5000
# glucose   768.0  120.566406   33.190074 -126.000   99.00000  117.0000
# pressure  768.0   69.105469   19.355807    0.000   62.00000   72.0000
# triceps   768.0   20.536458   15.952218    0.000    0.00000   23.0000
# insulin   768.0   79.799479  115.244002    0.000    0.00000   30.5000
# mass      768.0   31.992578    7.884160    0.000   27.30000   32.0000
# pedigree  768.0    0.471876    0.331329    0.078    0.24375    0.3725
# age       768.0   33.563802   16.022754  -26.000   24.00000   29.0000
# diabetes  768.0    0.348958    0.476951    0.000    0.00000    0.0000
#
#                 75%     max
# Sl.No     576.25000  768.00
# glucose   140.25000  199.00
# pressure   80.00000  122.00
# triceps    32.00000   99.00
# insulin   127.25000  846.00
# mass       36.60000   67.10
# pedigree    0.62625    2.42
# age        41.00000  329.00
# ...

# %%
df2['pregnant'].dtype
# Out:
# dtype('O')

# %%
df2.loc[df2['pregnant'] == '?','pregnant'] = np.nan

# %%
df2.loc[df2['pregnant'] == '@' , 'pregnant'] = np.nan

# %%
df2.isna().sum()
# Out:
# Sl.No       0
# pregnant    3
# glucose     0
# pressure    0
# triceps     0
# insulin     0
# mass        0
# pedigree    0
# age         0
# diabetes    0
# dtype: int64

# %%
df2['pregnant'].astype('float64')
# Out:
# 0       6.0
# 1       1.0
# 2       8.0
# 3       1.0
# 4       0.0
#        ...
# 763    10.0
# 764     2.0
# 765     5.0
# 766     1.0
# 767     1.0
# Name: pregnant, Length: 768, dtype: float64
